# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data/income_evaluation.csv')
df.head()
# Out:
#    age          workclass   fnlwgt   education   education-num  \
# 0   39          State-gov    77516   Bachelors              13
# 1   50   Self-emp-not-inc    83311   Bachelors              13
# 2   38            Private   215646     HS-grad               9
# 3   53            Private   234721        11th               7
# 4   28            Private   338409   Bachelors              13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#     capital-gain   capital-loss   hours-per-week  native-country  income
# 0           2174              0               40   United-States   <=50K
# 1              0              0               13   United-States   <=50K
# 2              0              0               40   United-States   <=50K
# 3              0              0               40   United-States   <=50K
# 4              0              0               40            Cuba   <=50K

# %%
df.shape
# Out:
# (32561, 15)

# %%
df = df.sample(frac=1)

# %%
df
# Out:
#        age          workclass   fnlwgt      education   education-num  \
# 23110   35            Private   381583   Some-college              10
# 24679   31            Private   209101    Prof-school              15
# 7302    19            Private   144161        HS-grad               9
# 24646   35            Private   144608        HS-grad               9
# 27295   36            Private   549174        HS-grad               9
# 1873    32          State-gov   171111      Bachelors              13
# 29873   43   Self-emp-not-inc   116666    Prof-school              15
# 23839   36            Private   225516     Assoc-acdm              12
# 1574    49                  ?   261059           10th               6
# 29070   36            Private    98515      Assoc-voc              11
# 16485   38          State-gov   312528      Bachelors              13
# 13464   45            Private   162915   Some-college              10
# 32172   36            Private    54229     Assoc-acdm              12
# 26925   27            Private   279608        5th-6th               3
# 23488   40            Private   283174      Assoc-voc              11
# 10954   68          Local-gov   177596           10th               6
# 16791   26          State-gov   152457        HS-grad               9
# 24909   32            Private   232855        HS-grad               9
# 17112   46            Private   198774        Masters              14
# 17123   46            Private   116666        HS-grad               9
# 26755   23            Private   265356      Bachelors              13
# 24007   25            Private   469572   Some-college              10
# 7060    46        Federal-gov   297906      Bachelors              13
# 8800    36          Local-gov   247807      Assoc-voc              11
# 18571   53            Private    89587   Some-college              10
# 2436    31          State-gov   151763        Masters              14
# 13225   22            Private    60331   Some-college              10
# 27590   36                  ?    98776   Some-college              10
# 32462   48       Self-emp-inc   185041        HS-grad               9
# 21730   17            Private   202344           10th               6
# ...    ...                ...      ...            ...             ...
# 30792   42            Private    33126     Assoc-acdm              12
# 31714   43            Private   169628      Bachelors              13
# 7236    40            Private   204046           10th               6
# 22032   26            Private   104834        Masters              14
# 13156   34            Private   346275           11th               7
# 3765    55            Private   171780     Assoc-acdm              12
# 30892   52            Private   222646           12th               8
# 16105   32          State-gov   177216      Bachelors              13
# 12298   28            Private    66473        HS-grad               9
# 3988    52            Private   192390        HS-grad               9
# 21773   23            Private   343019           10th               6
# 3146    32                  ?   199244           10th               6
# 23425   35            Private   126675        HS-grad               9
# 22220   90            Private    52386      Bachelors              13
# 21929   42            Private   144002        HS-grad               9
# 12079   26            Private   245465     Assoc-acdm              12
# 30715   31            Private   129775      Bachelors              13
# 25515   20            Private   388156   Some-college              10
# 19717   39   Self-emp-not-inc   163204        HS-grad               9
# 6111    39            Private    91711        Masters              14
# 32387   20            Private   176321   Some-college              10
# 31710   64                  ?    34100   Some-college              10
# 1426    45       Self-emp-inc    36228      Bachelors              13
# 8370    56       Self-emp-inc    35723        7th-8th               4
# 17169   40            Private   374367      Assoc-voc              11
# 27371   47            Private   423222    Prof-school              15
# 15837   47            Private   343579        1st-4th               2
# 28783   68                  ?   270339           10th               6
# 30236   23          State-gov   314645     Assoc-acdm              12
# 31213   23            Private   129345   Some-college              10
#
#                marital-status          occupation     relationship  \
# 23110      Married-civ-spouse        Craft-repair          Husband
# 24679      Married-civ-spouse      Prof-specialty          Husband
# 7302            Never-married    Transport-moving        Own-child
# 24646      Married-civ-spouse   Machine-op-inspct          Husband
# 27295      Married-civ-spouse        Craft-repair          Husband
# 1873            Never-married        Adm-clerical    Not-in-family
# 29873      Married-civ-spouse      Prof-specialty          Husband
# 23839           Never-married               Sales    Not-in-family
# 1574                Separated                   ?        Own-child
# 29070                Divorced        Tech-support        Unmarried
# 16485      Married-civ-spouse     Exec-managerial          Husband
# 13464                Divorced    Transport-moving    Not-in-family
# 32172      Married-civ-spouse     Exec-managerial             Wife
# 26925      Married-civ-spouse     Farming-fishing          Husband
# 23488      Married-civ-spouse     Farming-fishing          Husband
# 10954               Separated       Other-service    Not-in-family
# 16791           Never-married     Protective-serv    Not-in-family
# 24909           Never-married   Machine-op-inspct        Unmarried
# 17112                Divorced     Exec-managerial        Unmarried
# 17123                Divorced     Exec-managerial    Not-in-family
# 26755           Never-married     Exec-managerial        Unmarried
# 24007           Never-married      Prof-specialty    Not-in-family
# 7060       Married-civ-spouse      Prof-specialty          Husband
# 8800            Never-married     Protective-serv    Not-in-family
# 18571      Married-civ-spouse    Transport-moving          Husband
# 2436            Never-married        Adm-clerical    Not-in-family
# 13225      Married-civ-spouse       Other-service          Husband
# 27590           Never-married                   ?    Not-in-family
# 32462      Married-civ-spouse        Craft-repair          Husband
# 21730           Never-married       Other-service        Own-child
# ...                       ...                 ...              ...
# 30792      Married-civ-spouse     Exec-managerial          Husband
# 31714           Never-married               Sales        Unmarried
# 7236                 Divorced    Transport-moving        Own-child
# 22032           Never-married      Prof-specialty    Not-in-family
# 13156                Divorced   Handlers-cleaners    Not-in-family
# 3765                 Divorced               Sales        Unmarried
# 30892               Separated   Machine-op-inspct   Other-relative
# 16105           Never-married      Prof-specialty    Not-in-family
# 12298      Married-civ-spouse   Machine-op-inspct          Husband
# 3988       Married-civ-spouse   Machine-op-inspct          Husband
# 21773           Never-married       Other-service    Not-in-family
# 3146                 Divorced                   ?    Not-in-family
# 23425      Married-civ-spouse     Exec-managerial          Husband
# 22220           Never-married      Prof-specialty    Not-in-family
# 21929                Divorced    Transport-moving    Not-in-family
# 12079           Never-married               Sales        Own-child
# 30715      Married-civ-spouse               Sales          Husband
# 25515           Never-married      Prof-specialty        Own-child
# 19717      Married-civ-spouse               Sales          Husband
# 6111       Married-civ-spouse     Exec-managerial          Husband
# 32387           Never-married        Adm-clerical   Other-relative
# 31710                 Widowed                   ?    Not-in-family
# 1426       Married-civ-spouse     Farming-fishing          Husband
# 8370       Married-civ-spouse        Craft-repair          Husband
# 17169               Separated               Sales    Not-in-family
# 27371      Married-civ-spouse     Exec-managerial          Husband
# 15837   Married-spouse-absent     Farming-fishing    Not-in-family
# 28783      Married-civ-spouse                   ?          Husband
# 30236           Never-married        Adm-clerical    Not-in-family
# 31213           Never-married       Other-service    Not-in-family
#
#                       race      sex   capital-gain   capital-loss  \
# 23110                Other     Male              0              0
# 24679                White     Male              0              0
# 7302                 White     Male              0              0
# 24646                White     Male              0              0
# 27295                White     Male              0              0
# 1873                 White     Male              0              0
# 29873                Other     Male              0              0
# 23839                Black     Male          10520              0
# 1574                 White     Male           2176              0
# 29070                White   Female              0              0
# 16485                White     Male              0              0
# 13464                White     Male              0              0
# 32172                White   Female              0              0
# 26925                White     Male              0              0
# 23488                White     Male              0              0
# 10954                Black   Female              0              0
# 16791                White     Male              0              0
# 24909                Black   Female              0              0
# 17112                White   Female              0            323
# 17123                White   Female              0              0
# 26755                White     Male              0              0
# 24007                White     Male           8614              0
# 7060    Asian-Pac-Islander     Male              0              0
# 8800                 White     Male              0              0
# 18571                White     Male           7298              0
# 2436                 White     Male              0              0
# 13225                White     Male              0              0
# 27590                White     Male              0              0
# 32462                White     Male           7298              0
# 21730                White     Male              0              0
# ...                    ...      ...            ...            ...
# 30792                White     Male              0              0
# 31714                Black   Female              0              0
# 7236                 White     Male              0              0
# 22032                White   Female              0           1669
# 13156                White     Male              0              0
# 3765                 Black   Female              0              0
# 30892                White   Female              0              0
# 16105                White   Female              0              0
# 12298                White     Male              0              0
# 3988                 White     Male              0              0
# 21773                White   Female              0              0
# 3146                 White   Female              0              0
# 23425                White     Male              0              0
# 22220   Asian-Pac-Islander     Male              0              0
# 21929                White     Male              0              0
# 12079                White     Male              0              0
# 30715                White     Male              0              0
# 25515                White     Male              0              0
# 19717                White     Male              0              0
# 6111                 White     Male              0              0
# 32387                White   Female              0              0
# 31710                White     Male              0              0
# 1426                 White     Male           4386              0
# 8370                 White     Male              0              0
# 17169                Black     Male              0              0
# 27371                White     Male              0              0
# 15837                White     Male              0              0
# 28783                White     Male              0              0
# 30236                White   Female              0              0
# 31213                White     Male              0              0
#
#         hours-per-week  native-country  income
# 23110               45   United-States    >50K
# 24679               25   United-States    >50K
# 7302                30   United-States   <=50K
# 24646               40   United-States   <=50K
# 27295               40   United-States   <=50K
# 1873                37   United-States   <=50K
# 29873               35   United-States    >50K
# 23839               43   United-States    >50K
# 1574                40   United-States   <=50K
# 29070               40   United-States   <=50K
# 16485               37   United-States   <=50K
# 13464               50   United-States   <=50K
# 32172               37   United-States   <=50K
# 26925               40          Mexico   <=50K
# 23488               60   United-States   <=50K
# 10954               90   United-States   <=50K
# 16791               40   United-States   <=50K
# 24909               40   United-States   <=50K
# 17112               45   United-States   <=50K
# 17123               40   United-States   <=50K
# 26755               40   United-States   <=50K
# 24007               40   United-States    >50K
# 7060                50   United-States    >50K
# 8800                40   United-States    >50K
# 18571               45   United-States    >50K
# 2436                25   United-States   <=50K
# 13225               35   United-States   <=50K
# 27590               30   United-States   <=50K
# 32462               50   United-States    >50K
# 21730               25   United-States   <=50K
# ...                ...             ...     ...
# 30792               60   United-States    >50K
# 31714               35   United-States    >50K
# 7236                40   United-States   <=50K
# 22032               40   United-States   <=50K
# 13156               43   United-States   <=50K
# 3765                30   United-States   <=50K
# 30892               40            Cuba   <=50K
# 16105               40   United-States   <=50K
# 12298               40   United-States   <=50K
# 3988                40   United-States    >50K
# 21773               40   United-States   <=50K
# 3146                40   United-States   <=50K
# 23425               48   United-States   <=50K
# 22220               40   United-States   <=50K
# 21929               50   United-States   <=50K
# 12079               30   United-States   <=50K
# 30715               65   United-States   <=50K
# 25515               24   United-States   <=50K
# 19717               40   United-States   <=50K
# 6111                40   United-States    >50K
# 32387               20   United-States   <=50K
# 31710                4   United-States   <=50K
# 1426                35   United-States    >50K
# 8370                50   United-States    >50K
# 17169               44   United-States   <=50K
# 27371               45   United-States    >50K
# 15837               12          Mexico   <=50K
# 28783               35   United-States   <=50K
# 30236               25   United-States   <=50K
# 31213               25   United-States   <=50K
#
# [32561 rows x 15 columns]

# %%
len(df) * 0.8
# Out:
# 26048.800000000003

# %%
train = df[:26048]

# %%
test = df[26048:]

# %%
train.head()
# Out:
#        age  workclass   fnlwgt      education   education-num  \
# 23110   35    Private   381583   Some-college              10
# 24679   31    Private   209101    Prof-school              15
# 7302    19    Private   144161        HS-grad               9
# 24646   35    Private   144608        HS-grad               9
# 27295   36    Private   549174        HS-grad               9
#
#             marital-status          occupation  relationship    race    sex  \
# 23110   Married-civ-spouse        Craft-repair       Husband   Other   Male
# 24679   Married-civ-spouse      Prof-specialty       Husband   White   Male
# 7302         Never-married    Transport-moving     Own-child   White   Male
# 24646   Married-civ-spouse   Machine-op-inspct       Husband   White   Male
# 27295   Married-civ-spouse        Craft-repair       Husband   White   Male
#
#         capital-gain   capital-loss   hours-per-week  native-country  income
# 23110              0              0               45   United-States    >50K
# 24679              0              0               25   United-States    >50K
# 7302               0              0               30   United-States   <=50K
# 24646              0              0               40   United-States   <=50K
# 27295              0              0               40   United-States   <=50K

# %%
train.columns
# Out:
# Index(['age', ' workclass', ' fnlwgt', ' education', ' education-num',
#        ' marital-status', ' occupation', ' relationship', ' race', ' sex',
#        ' capital-gain', ' capital-loss', ' hours-per-week', ' native-country',
#        ' income'],
#       dtype='object')

# %%
train.columns = train.columns.str.lstrip()

# %%
test.columns = test.columns.str.lstrip()

# %%
X_train = train.drop('income', axis=1)

# %%
X_train.head()
# Out:
#        age workclass  fnlwgt      education  education-num  \
# 23110   35   Private  381583   Some-college             10
# 24679   31   Private  209101    Prof-school             15
# 7302    19   Private  144161        HS-grad              9
# 24646   35   Private  144608        HS-grad              9
# 27295   36   Private  549174        HS-grad              9
#
#             marital-status          occupation relationship    race    sex  \
# 23110   Married-civ-spouse        Craft-repair      Husband   Other   Male
# 24679   Married-civ-spouse      Prof-specialty      Husband   White   Male
# 7302         Never-married    Transport-moving    Own-child   White   Male
# 24646   Married-civ-spouse   Machine-op-inspct      Husband   White   Male
# 27295   Married-civ-spouse        Craft-repair      Husband   White   Male
#
#        capital-gain  capital-loss  hours-per-week  native-country
# 23110             0             0              45   United-States
# 24679             0             0              25   United-States
# 7302              0             0              30   United-States
# 24646             0             0              40   United-States
# 27295             0             0              40   United-States

# %%
y_train = train.income

# %%
y_train
# Out:
# 23110      >50K
# 24679      >50K
# 7302      <=50K
# 24646     <=50K
# 27295     <=50K
# 1873      <=50K
# 29873      >50K
# 23839      >50K
# 1574      <=50K
# 29070     <=50K
# 16485     <=50K
# 13464     <=50K
# 32172     <=50K
# 26925     <=50K
# 23488     <=50K
# 10954     <=50K
# 16791     <=50K
# 24909     <=50K
# 17112     <=50K
# 17123     <=50K
# 26755     <=50K
# 24007      >50K
# 7060       >50K
# 8800       >50K
# 18571      >50K
# 2436      <=50K
# 13225     <=50K
# 27590     <=50K
# 32462      >50K
# 21730     <=50K
#           ...
# 27596      >50K
# 28675      >50K
# 2417      <=50K
# 9853      <=50K
# 19928     <=50K
# 2792      <=50K
# 2784      <=50K
# 27376     <=50K
# 25344     <=50K
# 30270     <=50K
# 24886     <=50K
# 28145     <=50K
# 25141      >50K
# 19834     <=50K
# 28083     <=50K
# 177       <=50K
# 25895     <=50K
# 18511      >50K
# 585       <=50K
# 24229      >50K
# 28746      >50K
# 20508     <=50K
# 21976      >50K
# 21951     <=50K
# 9444      <=50K
# 30440     <=50K
# 28779     <=50K
# 27428      >50K
# 6923      <=50K
# 23965      >50K
# Name: income, Length: 26048, dtype: object

# %%
X_test = test.drop('income', axis='columns')

# %%
y_test = test.income

# %% [markdown]
# # Using sklearn's train_test_split

# %%
d = pd.read_csv('data/income_evaluation.csv')
d.head()
# Out:
#    age          workclass   fnlwgt   education   education-num  \
# 0   39          State-gov    77516   Bachelors              13
# 1   50   Self-emp-not-inc    83311   Bachelors              13
# 2   38            Private   215646     HS-grad               9
# 3   53            Private   234721        11th               7
# 4   28            Private   338409   Bachelors              13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#     capital-gain   capital-loss   hours-per-week  native-country  income
# 0           2174              0               40   United-States   <=50K
# 1              0              0               13   United-States   <=50K
# 2              0              0               40   United-States   <=50K
# 3              0              0               40   United-States   <=50K
# 4              0              0               40            Cuba   <=50K

# %%
from sklearn.model_selection import train_test_split

# %%
X = d.drop(' income', axis=1)
y = d[' income']

# %%
X1, X2, y1, y2 = train_test_split(X, y, test_size=0.2, random_state=0, stratify=y)

# %%
X1, X2, y1, y2 = train_test_split(X, y, test_size=0.2, random_state=0)
print(y1.value_counts())
print(y2.value_counts())
# Out:
#  <=50K    19802
#  >50K      6246
# Name:  income, dtype: int64
#  <=50K    4918
#  >50K     1595
# Name:  income, dtype: int64

# %%
6246/19802
# Out:
# 0.3154226845773154

# %%
1595/4918
# Out:
# 0.3243188287921919

# %%
y1.value_counts()
# Out:
#  <=50K    19775
#  >50K      6273
# Name:  income, dtype: int64

# %%
6273/19775
# Out:
# 0.3172187104930468

# %%
y2.value_counts()
# Out:
#  <=50K    4945
#  >50K     1568
# Name:  income, dtype: int64

# %%
1568/4945
# Out:
# 0.3170879676440849

# %%
X1
# Out:
#        age          workclass   fnlwgt      education   education-num  \
# 29101   19                  ?   140399   Some-college              10
# 10606   50            Private   158284   Some-college              10
# 9414    62            Private   183735   Some-college              10
# 1747    20            Private   154781        HS-grad               9
# 10677   25            Private   356344      Bachelors              13
# 14370   22                  ?   189203     Assoc-acdm              12
# 19403   21            Private   175374        HS-grad               9
# 23351   24                  ?   172152      Bachelors              13
# 14405   52            Private    31533        HS-grad               9
# 29604   30            Private   329425   Some-college              10
# 4472    46            Private   117502        HS-grad               9
# 11260   54            Private   225599        Masters              14
# 19236   17            Private   225106           10th               6
# 9371    23            Private   239539        HS-grad               9
# 29747   41   Self-emp-not-inc    44006      Assoc-voc              11
# 29635   37            Private   171150      Bachelors              13
# 32025   50            Private   139703   Some-college              10
# 25351   55            Private   189528        5th-6th               3
# 2608    23            Private   203240   Some-college              10
# 25534   45   Self-emp-not-inc   118081   Some-college              10
# 26396   36            Private   272944      Bachelors              13
# 6415    49        Federal-gov   311671   Some-college              10
# 14691   29            Private   375078        7th-8th               4
# 222     90            Private    51744        HS-grad               9
# 30079   36            Private    33394      Bachelors              13
# 3113    44            Private   198316      Bachelors              13
# 1113    69            Private   168139        HS-grad               9
# 3100    39            Private   278187        HS-grad               9
# 22983   56                  ?    32604   Some-college              10
# 32405   33            Private   168387           11th               7
# ...    ...                ...      ...            ...             ...
# 18757   36            Private   301227        5th-6th               3
# 28685   36            Private   172129            9th               5
# 31771   26            Private    31143   Some-college              10
# 13176   43            Private   149909        HS-grad               9
# 25927   25            Private   255474      Bachelors              13
# 18111   55            Private    98746   Some-college              10
# 12913   45            Private    77927      Bachelors              13
# 13386   32   Self-emp-not-inc   203408        HS-grad               9
# 17911   32            Private   222654           10th               6
# 13111   50   Self-emp-not-inc   219420      Doctorate              16
# 5644    48            Private   265083           10th               6
# 15809   58   Self-emp-not-inc   143731        HS-grad               9
# 19888   21            Private   353628           10th               6
# 7327    53          State-gov   104501      Doctorate              16
# 24907   28            Private   130067      Bachelors              13
# 24777   59            Private   121865        HS-grad               9
# 9488    38            Private   129591   Some-college              10
# 5701    56            Private   286487        HS-grad               9
# 1559    21            Private   236684   Some-college              10
# 18120   20            Private   109952   Some-college              10
# 15359   48            Private   299291        HS-grad               9
# 592     60            Private    39352        7th-8th               4
# 25149   33            Private   224258        7th-8th               4
# 23373   17                  ?   806316           11th               7
# 22972   47            Private   112791        HS-grad               9
# 11465   49            Private   278322        HS-grad               9
# 15326   32          Local-gov   223267        Masters              14
# 284     21            Private   205759        HS-grad               9
# 13784   73                  ?   191394    Prof-school              15
# 10618   53            Private   311350      Bachelors              13
#
#             marital-status          occupation     relationship  \
# 29101        Never-married                   ?   Other-relative
# 10606   Married-civ-spouse   Machine-op-inspct          Husband
# 9414    Married-civ-spouse     Exec-managerial          Husband
# 1747         Never-married        Adm-clerical    Not-in-family
# 10677        Never-married        Adm-clerical        Own-child
# 14370        Never-married                   ?   Other-relative
# 19403        Never-married        Adm-clerical        Own-child
# 23351        Never-married                   ?    Not-in-family
# 14405             Divorced       Other-service    Not-in-family
# 29604        Never-married     Protective-serv        Own-child
# 4472    Married-civ-spouse        Adm-clerical             Wife
# 11260   Married-civ-spouse      Prof-specialty          Husband
# 19236        Never-married       Other-service        Own-child
# 9371         Never-married   Machine-op-inspct        Own-child
# 29747             Divorced     Farming-fishing    Not-in-family
# 29635   Married-civ-spouse               Sales          Husband
# 32025   Married-civ-spouse        Craft-repair          Husband
# 25351   Married-civ-spouse        Craft-repair          Husband
# 2608         Never-married       Other-service    Not-in-family
# 25534   Married-civ-spouse       Other-service          Husband
# 26396   Married-civ-spouse     Exec-managerial          Husband
# 6415    Married-civ-spouse     Exec-managerial          Husband
# 14691   Married-civ-spouse       Other-service             Wife
# 222          Never-married       Other-service    Not-in-family
# 30079   Married-civ-spouse               Sales          Husband
# 3113    Married-civ-spouse     Exec-managerial          Husband
# 1113    Married-civ-spouse               Sales             Wife
# 3100    Married-civ-spouse   Machine-op-inspct          Husband
# 22983        Never-married                   ?    Not-in-family
# 32405   Married-civ-spouse       Other-service          Husband
# ...                    ...                 ...              ...
# 18757            Separated     Priv-house-serv        Unmarried
# 28685   Married-civ-spouse   Handlers-cleaners          Husband
# 31771        Never-married        Craft-repair    Not-in-family
# 13176   Married-civ-spouse        Craft-repair          Husband
# 25927        Never-married        Adm-clerical    Not-in-family
# 18111   Married-civ-spouse        Tech-support          Husband
# 12913              Widowed       Other-service        Own-child
# 13386   Married-civ-spouse        Craft-repair          Husband
# 17911             Divorced   Machine-op-inspct    Not-in-family
# 13111             Divorced               Sales    Not-in-family
# 5644              Divorced               Sales    Not-in-family
# 15809   Married-civ-spouse               Sales          Husband
# 19888            Separated               Sales        Unmarried
# 7327    Married-civ-spouse      Prof-specialty          Husband
# 24907   Married-civ-spouse      Prof-specialty             Wife
# 24777             Divorced       Other-service    Not-in-family
# 9488    Married-civ-spouse        Craft-repair          Husband
# 5701    Married-civ-spouse        Craft-repair          Husband
# 1559         Never-married       Other-service   Other-relative
# 18120        Never-married   Handlers-cleaners        Own-child
# 15359   Married-civ-spouse    Transport-moving          Husband
# 592          Never-married    Transport-moving    Not-in-family
# 25149        Never-married     Farming-fishing    Not-in-family
# 23373        Never-married                   ?        Own-child
# 22972   Married-civ-spouse     Protective-serv          Husband
# 11465   Married-civ-spouse        Craft-repair          Husband
# 15326   Married-civ-spouse      Prof-specialty          Husband
# 284          Never-married   Handlers-cleaners        Own-child
# 13784   Married-civ-spouse                   ?          Husband
# 10618   Married-civ-spouse     Exec-managerial          Husband
#
#                       race      sex   capital-gain   capital-loss  \
# 29101                White   Female              0              0
# 10606                White     Male              0              0
# 9414                 White     Male              0              0
# 1747                 White   Female              0              0
# 10677                White   Female              0              0
# 14370                White     Male              0              0
# 19403                White     Male              0              0
# 23351   Asian-Pac-Islander     Male              0              0
# 14405                White     Male              0              0
# 29604                White     Male              0              0
# 4472                 White   Female              0              0
# 11260   Asian-Pac-Islander     Male           7298              0
# 19236                White   Female              0           1602
# 9371    Asian-Pac-Islander     Male              0              0
# 29747                White     Male              0              0
# 29635                White     Male          99999              0
# 32025                White     Male              0              0
# 25351                White     Male              0              0
# 2608                 White   Female              0              0
# 25534                White     Male           3103              0
# 26396                White     Male              0           1887
# 6415                 White     Male              0              0
# 14691                White   Female              0              0
# 222                  Black     Male              0           2206
# 30079                White     Male              0           1887
# 3113                 White     Male          15024              0
# 1113                 White   Female              0              0
# 3100                 White     Male              0              0
# 22983                Black   Female              0              0
# 32405                White     Male              0              0
# ...                    ...      ...            ...            ...
# 18757                Other   Female              0              0
# 28685                White     Male              0              0
# 31771                White     Male              0              0
# 13176                White     Male              0              0
# 25927                White   Female              0              0
# 18111                White     Male              0              0
# 12913   Asian-Pac-Islander   Female              0              0
# 13386                White     Male              0              0
# 17911                White     Male              0              0
# 13111                White     Male              0              0
# 5644                 White   Female              0              0
# 15809                White     Male              0              0
# 19888                Black   Female              0              0
# 7327                 White     Male              0              0
# 24907                White   Female              0              0
# 24777                Black   Female              0              0
# 9488                 White     Male              0              0
# 5701                 White     Male           2885              0
# 1559                 Black   Female              0              0
# 18120                White     Male              0              0
# 15359                White     Male              0              0
# 592                  White     Male              0              0
# 25149                White     Male              0              0
# 23373                White   Female              0              0
# 22972                White     Male              0              0
# 11465                White     Male              0              0
# 15326                White     Male              0              0
# 284                  White     Male              0              0
# 13784                White     Male              0              0
# 10618                White     Male              0              0
#
#         hours-per-week  native-country
# 29101               30   United-States
# 10606               40   United-States
# 9414                40   United-States
# 1747                40   United-States
# 10677               40   United-States
# 14370               15   United-States
# 19403               40   United-States
# 23351               25          Taiwan
# 14405               40   United-States
# 29604               48   United-States
# 4472                40   United-States
# 11260               40           India
# 19236               18   United-States
# 9371                40     Philippines
# 29747               40   United-States
# 29635               60   United-States
# 32025               40   United-States
# 25351               50   United-States
# 2608                40   United-States
# 25534               42   United-States
# 26396               40   United-States
# 6415                40   United-States
# 14691               40          Mexico
# 222                 40   United-States
# 30079               35   United-States
# 3113                50   United-States
# 1113                40   United-States
# 3100                40   United-States
# 22983               40   United-States
# 32405               40   United-States
# ...                ...             ...
# 18757               35          Mexico
# 28685               40   United-States
# 31771               40   United-States
# 13176               42   United-States
# 25927               40   United-States
# 18111               50          Canada
# 12913               40     Philippines
# 13386               44   United-States
# 17911               40   United-States
# 13111               64   United-States
# 5644                38   United-States
# 15809               72   United-States
# 19888               38   United-States
# 7327                40               ?
# 24907               40   United-States
# 24777               40   United-States
# 9488                40   United-States
# 5701                45   United-States
# 1559                 8   United-States
# 18120               25   United-States
# 15359               44   United-States
# 592                 48   United-States
# 25149               40          Mexico
# 23373               20   United-States
# 22972               40   United-States
# 11465               40   United-States
# 15326               48   United-States
# 284                 40   United-States
# 13784               40   United-States
# 10618               50   United-States
#
# [26048 rows x 14 columns]
