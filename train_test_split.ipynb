# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data/income_evaluation.csv')
df.head()
# Out:
#    age          workclass   fnlwgt   education   education-num  \
# 0   39          State-gov    77516   Bachelors              13
# 1   50   Self-emp-not-inc    83311   Bachelors              13
# 2   38            Private   215646     HS-grad               9
# 3   53            Private   234721        11th               7
# 4   28            Private   338409   Bachelors              13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#     capital-gain   capital-loss   hours-per-week  native-country  income
# 0           2174              0               40   United-States   <=50K
# 1              0              0               13   United-States   <=50K
# 2              0              0               40   United-States   <=50K
# 3              0              0               40   United-States   <=50K
# 4              0              0               40            Cuba   <=50K

# %%
df.shape
# Out:
# (32561, 15)

# %%
df = df.sample(frac=1)

# %%
df
# Out:
#        age          workclass   fnlwgt      education   education-num  \
# 1755    25            Private   169323      Bachelors              13
# 29885   46            Private   336984        HS-grad               9
# 2645    46            Private   138626   Some-college              10
# 18893   53          Local-gov   197054        Masters              14
# 9468    40          State-gov   199381        Masters              14
# 6071    57   Self-emp-not-inc   286836           10th               6
# 17713   21            Private   189013   Some-college              10
# 15468   29            Private    37933           12th               8
# 22801   26            Private   149734        HS-grad               9
# 11061   43       Self-emp-inc   175715        HS-grad               9
# 1614    26            Private   161007      Bachelors              13
# 10129   37            Private   167851        HS-grad               9
# 21154   22            Private   219042           10th               6
# 31706   29            Private    50295   Some-college              10
# 21380   60            Private   186446        7th-8th               4
# 16798   51                  ?   146325        HS-grad               9
# 29356   52   Self-emp-not-inc   138611        HS-grad               9
# 13425   75   Self-emp-not-inc    92792        HS-grad               9
# 19655   32            Private   207668      Bachelors              13
# 5406    90            Private    51744        Masters              14
# 5505    29            Private   632593        HS-grad               9
# 24850   48            Private   107231    Prof-school              15
# 21058   44   Self-emp-not-inc   172479        HS-grad               9
# 6223    27            Private    72208   Some-college              10
# 11371   63            Private   203783        HS-grad               9
# 21087   70            Private   280307      Bachelors              13
# 25102   51            Private    55500           12th               8
# 6200    37   Self-emp-not-inc   415847      Bachelors              13
# 843     62          Local-gov   291175      Bachelors              13
# 23173   19            Private   254247           12th               8
# ...    ...                ...      ...            ...             ...
# 1517    59            Private   284834      Bachelors              13
# 18118   39            Private   280570      Bachelors              13
# 28845   31            Private   272856        HS-grad               9
# 31298   29        Federal-gov   242147        HS-grad               9
# 23143   26            Private   456618        HS-grad               9
# 2261    27            Private   408623      Bachelors              13
# 6441    28            Private   338376      Bachelors              13
# 21784   32            Private   248584        HS-grad               9
# 3661    57            Private   145189   Some-college              10
# 24586   33            Private   189265      Bachelors              13
# 4850    60   Self-emp-not-inc   376973        HS-grad               9
# 1285    46            Private   188861   Some-college              10
# 22829   61        Federal-gov   151369    Prof-school              15
# 30965   54          Local-gov   127943        HS-grad               9
# 29441   61            Private   316359   Some-college              10
# 14845   20            Private    60639   Some-college              10
# 208     58       Self-emp-inc   210563        HS-grad               9
# 8007    44                  ?   174147   Some-college              10
# 15493   67       Self-emp-inc    81413        HS-grad               9
# 6       49            Private   160187            9th               5
# 26081   40                  ?   165309        7th-8th               4
# 2828    54   Self-emp-not-inc   175804      Bachelors              13
# 17008   38          Local-gov   236687   Some-college              10
# 20417   42       Self-emp-inc    23510        Masters              14
# 21278   19            Private   194905   Some-college              10
# 23656   25            Private   176047        HS-grad               9
# 9858    35            Private   474136        HS-grad               9
# 28150   46            Private   208067        HS-grad               9
# 32333   37       Self-emp-inc   328466   Some-college              10
# 30986   31          Local-gov    94991        HS-grad               9
#
#                marital-status          occupation     relationship  \
# 1755       Married-civ-spouse     Exec-managerial        Own-child
# 29885           Never-married   Handlers-cleaners        Own-child
# 2645       Married-civ-spouse        Craft-repair          Husband
# 18893      Married-civ-spouse      Prof-specialty          Husband
# 9468       Married-civ-spouse      Prof-specialty             Wife
# 6071       Married-civ-spouse        Craft-repair          Husband
# 17713           Never-married               Sales        Own-child
# 15468   Married-spouse-absent       Other-service    Not-in-family
# 22801               Separated        Craft-repair        Unmarried
# 11061           Never-married     Exec-managerial    Not-in-family
# 1614            Never-married        Adm-clerical        Own-child
# 10129      Married-civ-spouse        Craft-repair          Husband
# 21154           Never-married   Machine-op-inspct        Unmarried
# 31706      Married-civ-spouse     Exec-managerial          Husband
# 21380      Married-civ-spouse   Machine-op-inspct             Wife
# 16798      Married-civ-spouse                   ?          Husband
# 29356      Married-civ-spouse               Sales          Husband
# 13425      Married-civ-spouse               Sales          Husband
# 19655           Never-married     Exec-managerial   Other-relative
# 5406            Never-married     Exec-managerial    Not-in-family
# 5505       Married-civ-spouse        Craft-repair          Husband
# 24850      Married-civ-spouse     Exec-managerial          Husband
# 21058      Married-civ-spouse     Farming-fishing          Husband
# 6223            Never-married        Adm-clerical        Own-child
# 11371                Divorced      Prof-specialty    Not-in-family
# 21087      Married-civ-spouse     Exec-managerial          Husband
# 25102      Married-civ-spouse    Transport-moving          Husband
# 6200       Married-civ-spouse      Prof-specialty          Husband
# 843                   Widowed      Prof-specialty    Not-in-family
# 23173           Never-married        Adm-clerical        Own-child
# ...                       ...                 ...              ...
# 1517       Married-civ-spouse        Adm-clerical             Wife
# 18118      Married-civ-spouse     Exec-managerial          Husband
# 28845           Never-married        Craft-repair        Own-child
# 31298                Divorced        Adm-clerical    Not-in-family
# 23143           Never-married       Other-service    Not-in-family
# 2261       Married-civ-spouse        Craft-repair   Other-relative
# 6441            Never-married      Prof-specialty        Own-child
# 21784           Never-married     Farming-fishing        Own-child
# 3661            Never-married        Adm-clerical    Not-in-family
# 24586           Never-married     Exec-managerial    Not-in-family
# 4850       Married-civ-spouse        Craft-repair          Husband
# 1285       Married-civ-spouse    Transport-moving          Husband
# 22829      Married-civ-spouse      Prof-specialty          Husband
# 30965                 Widowed       Other-service        Unmarried
# 29441                Divorced               Sales    Not-in-family
# 14845           Never-married               Sales        Own-child
# 208        Married-civ-spouse               Sales             Wife
# 8007       Married-civ-spouse                   ?          Husband
# 15493      Married-civ-spouse    Transport-moving          Husband
# 6       Married-spouse-absent       Other-service    Not-in-family
# 26081               Separated                   ?    Not-in-family
# 2828       Married-civ-spouse     Exec-managerial          Husband
# 17008           Never-married      Prof-specialty        Own-child
# 20417                Divorced     Exec-managerial        Unmarried
# 21278           Never-married       Other-service        Own-child
# 23656           Never-married   Machine-op-inspct        Own-child
# 9858            Never-married        Craft-repair    Not-in-family
# 28150                Divorced        Craft-repair   Other-relative
# 32333      Married-civ-spouse     Exec-managerial          Husband
# 30986                Divorced       Other-service        Unmarried
#
#                       race      sex   capital-gain   capital-loss  \
# 1755                 White   Female              0              0
# 29885                White     Male              0              0
# 2645                 White     Male              0              0
# 18893                White     Male              0              0
# 9468                 White   Female          15024              0
# 6071                 White     Male              0              0
# 17713                White   Female              0              0
# 15468                Black   Female              0              0
# 22801                Black   Female              0           1594
# 11061                Black     Male              0              0
# 1614                 White     Male              0              0
# 10129                White     Male              0              0
# 21154                White     Male              0              0
# 31706                White     Male              0              0
# 21380                White   Female              0              0
# 16798                White     Male              0              0
# 29356                White     Male           7688              0
# 13425                White     Male              0              0
# 19655                White     Male              0           2444
# 5406                 Black     Male              0              0
# 5505                 Black     Male              0              0
# 24850                White     Male          99999              0
# 21058                White     Male          15024              0
# 6223                 Black     Male              0              0
# 11371                White   Female              0              0
# 21087                White     Male              0              0
# 25102                White     Male              0              0
# 6200                 White     Male              0              0
# 843                  White   Female              0              0
# 23173                White     Male              0              0
# ...                    ...      ...            ...            ...
# 1517                 White   Female           2885              0
# 18118                White     Male              0              0
# 28845                Black     Male              0              0
# 31298                Other     Male              0              0
# 23143                White     Male              0              0
# 2261                 White     Male              0              0
# 6441                 White     Male              0              0
# 21784                White     Male              0              0
# 3661                 White   Female              0              0
# 24586                White   Female              0              0
# 4850                 White     Male              0              0
# 1285                 White     Male              0              0
# 22829                White     Male              0              0
# 30965                Black   Female              0              0
# 29441                White   Female              0              0
# 14845                White   Female              0              0
# 208                  White   Female          15024              0
# 8007                 White     Male              0              0
# 15493                White     Male              0              0
# 6                    Black   Female              0              0
# 26081                White   Female              0              0
# 2828                 White     Male              0              0
# 17008                White     Male              0              0
# 20417   Asian-Pac-Islander     Male              0           2201
# 21278                White   Female              0              0
# 23656                White   Female           2176              0
# 9858                 White     Male              0           1408
# 28150                White     Male              0              0
# 32333                White     Male              0              0
# 30986   Amer-Indian-Eskimo     Male              0              0
#
#         hours-per-week  native-country  income
# 1755                40   United-States   <=50K
# 29885               17   United-States   <=50K
# 2645                40   United-States   <=50K
# 18893               40   United-States    >50K
# 9468                37   United-States    >50K
# 6071                 8   United-States   <=50K
# 17713               35   United-States   <=50K
# 15468               40   United-States   <=50K
# 22801               40   United-States   <=50K
# 11061               55   United-States   <=50K
# 1614                30   United-States   <=50K
# 10129               50   United-States   <=50K
# 21154               40   United-States   <=50K
# 31706               48   United-States   <=50K
# 21380               40   United-States   <=50K
# 16798               28   United-States   <=50K
# 29356               55   United-States    >50K
# 13425               35   United-States   <=50K
# 19655               50   United-States    >50K
# 5406                50   United-States    >50K
# 5505                40   United-States   <=50K
# 24850               50   United-States    >50K
# 21058               60   United-States    >50K
# 6223                40   United-States   <=50K
# 11371               72   United-States   <=50K
# 21087               20            Cuba   <=50K
# 25102               40   United-States   <=50K
# 6200                40   United-States    >50K
# 843                 48   United-States   <=50K
# 23173               38               ?   <=50K
# ...                ...             ...     ...
# 1517                30   United-States   <=50K
# 18118               45   United-States   <=50K
# 28845               50         England   <=50K
# 31298               45   United-States   <=50K
# 23143               40          Mexico   <=50K
# 2261                50   United-States   <=50K
# 6441                40   United-States   <=50K
# 21784               40   United-States   <=50K
# 3661                40   United-States   <=50K
# 24586               40   United-States   <=50K
# 4850                42   United-States    >50K
# 1285                40   United-States   <=50K
# 22829               50   United-States    >50K
# 30965               40   United-States   <=50K
# 29441               40   United-States   <=50K
# 14845               28   United-States   <=50K
# 208                 35   United-States    >50K
# 8007                40   United-States   <=50K
# 15493               40   United-States   <=50K
# 6                   16         Jamaica   <=50K
# 26081                8   United-States   <=50K
# 2828                40   United-States    >50K
# 17008               40   United-States   <=50K
# 20417               60           India    >50K
# 21278               12   United-States   <=50K
# 23656               40   United-States   <=50K
# 9858                40   United-States   <=50K
# 28150               40   United-States   <=50K
# 32333               50   United-States    >50K
# 30986               40   United-States   <=50K
#
# [32561 rows x 15 columns]

# %%
len(df) * 0.8
# Out:
# 26048.800000000003

# %%
train = df[:26048]

# %%
test = df[26048:]

# %%
train.head()
# Out:
#        age   workclass   fnlwgt      education   education-num  \
# 1755    25     Private   169323      Bachelors              13
# 29885   46     Private   336984        HS-grad               9
# 2645    46     Private   138626   Some-college              10
# 18893   53   Local-gov   197054        Masters              14
# 9468    40   State-gov   199381        Masters              14
#
#             marital-status          occupation  relationship    race      sex  \
# 1755    Married-civ-spouse     Exec-managerial     Own-child   White   Female
# 29885        Never-married   Handlers-cleaners     Own-child   White     Male
# 2645    Married-civ-spouse        Craft-repair       Husband   White     Male
# 18893   Married-civ-spouse      Prof-specialty       Husband   White     Male
# 9468    Married-civ-spouse      Prof-specialty          Wife   White   Female
#
#         capital-gain   capital-loss   hours-per-week  native-country  income
# 1755               0              0               40   United-States   <=50K
# 29885              0              0               17   United-States   <=50K
# 2645               0              0               40   United-States   <=50K
# 18893              0              0               40   United-States    >50K
# 9468           15024              0               37   United-States    >50K

# %%
train.columns
# Out:
# Index(['age', ' workclass', ' fnlwgt', ' education', ' education-num',
#        ' marital-status', ' occupation', ' relationship', ' race', ' sex',
#        ' capital-gain', ' capital-loss', ' hours-per-week', ' native-country',
#        ' income'],
#       dtype='object')

# %%
train.columns = train.columns.str.lstrip()

# %%
test.columns = test.columns.str.lstrip()

# %%
X_train = train.drop('income', axis=1)

# %%
X_train.head()
# Out:
#        age   workclass  fnlwgt      education  education-num  \
# 1755    25     Private  169323      Bachelors             13
# 29885   46     Private  336984        HS-grad              9
# 2645    46     Private  138626   Some-college             10
# 18893   53   Local-gov  197054        Masters             14
# 9468    40   State-gov  199381        Masters             14
#
#             marital-status          occupation relationship    race      sex  \
# 1755    Married-civ-spouse     Exec-managerial    Own-child   White   Female
# 29885        Never-married   Handlers-cleaners    Own-child   White     Male
# 2645    Married-civ-spouse        Craft-repair      Husband   White     Male
# 18893   Married-civ-spouse      Prof-specialty      Husband   White     Male
# 9468    Married-civ-spouse      Prof-specialty         Wife   White   Female
#
#        capital-gain  capital-loss  hours-per-week  native-country
# 1755              0             0              40   United-States
# 29885             0             0              17   United-States
# 2645              0             0              40   United-States
# 18893             0             0              40   United-States
# 9468          15024             0              37   United-States

# %%
y_train = train.income

# %%
y_train.head()
# Out:
# 1755      <=50K
# 29885     <=50K
# 2645      <=50K
# 18893      >50K
# 9468       >50K
# Name: income, dtype: object

# %%
X_test = test.drop('income', axis='columns')

# %%
y_test = test.income

# %% [markdown]
# # Using sklearn's train_test_split

# %%
d = pd.read_csv('data/income_evaluation.csv')
d.head()
# Out:
#    age          workclass   fnlwgt   education   education-num  \
# 0   39          State-gov    77516   Bachelors              13
# 1   50   Self-emp-not-inc    83311   Bachelors              13
# 2   38            Private   215646     HS-grad               9
# 3   53            Private   234721        11th               7
# 4   28            Private   338409   Bachelors              13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#     capital-gain   capital-loss   hours-per-week  native-country  income
# 0           2174              0               40   United-States   <=50K
# 1              0              0               13   United-States   <=50K
# 2              0              0               40   United-States   <=50K
# 3              0              0               40   United-States   <=50K
# 4              0              0               40            Cuba   <=50K

# %%
from sklearn.model_selection import train_test_split

# %%
X = d.drop(' income', axis=1)
y = d[' income']

# %%
X1, X2, y1, y2 = train_test_split(X, y, test_size=0.2, random_state=0, stratify=y)

# %%
y1.value_counts()
# Out:
#  <=50K    19775
#  >50K      6273
# Name:  income, dtype: int64

# %%
y2.value_counts()
# Out:
#  <=50K    4945
#  >50K     1568
# Name:  income, dtype: int64

# %%
y.value_counts()
# Out:
#  <=50K    24720
#  >50K      7841
# Name:  income, dtype: int64

# %% [markdown]
# 24720 is the total number of "<=50K" data samples. <br>These will be split in the ratio of 80:20

# %% [markdown]
# In the 'training y', i.e. y1, we'll have 24720 * 0.8 = 19776 "<=50K" samples

# %%
24720*0.8
# Out:
# 19776.0

# %% [markdown]
# In the 'testing y', i.e. y2, we'll have 24720 * 0.2 = 4944 "<=50K" samples

# %%
24720*0.2
# Out:
# 4944.0

# %% [markdown]
# 7841 is the total number of ">50K" data samples. <br>These will be split in the ratio of 80:20

# %% [markdown]
# In the 'testing y', i.e. y2, we'll have 7841 * 0.2 = 1568 ">50K" samples (rounding off)

# %%
7841*0.2
# Out:
# 1568.2

# %% [markdown]
# In the 'training y', i.e. y1, we'll have 7841 * 0.8 = 6273 ">50K" samples (rounding off)

# %%
7841*0.8
# Out:
# 6272.8

# %%
X1.head()
# Out:
#        age  workclass   fnlwgt      education   education-num  \
# 29101   19          ?   140399   Some-college              10
# 10606   50    Private   158284   Some-college              10
# 9414    62    Private   183735   Some-college              10
# 1747    20    Private   154781        HS-grad               9
# 10677   25    Private   356344      Bachelors              13
#
#             marital-status          occupation     relationship    race  \
# 29101        Never-married                   ?   Other-relative   White
# 10606   Married-civ-spouse   Machine-op-inspct          Husband   White
# 9414    Married-civ-spouse     Exec-managerial          Husband   White
# 1747         Never-married        Adm-clerical    Not-in-family   White
# 10677        Never-married        Adm-clerical        Own-child   White
#
#            sex   capital-gain   capital-loss   hours-per-week  native-country
# 29101   Female              0              0               30   United-States
# 10606     Male              0              0               40   United-States
# 9414      Male              0              0               40   United-States
# 1747    Female              0              0               40   United-States
# 10677   Female              0              0               40   United-States
